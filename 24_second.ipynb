# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
basketball_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_stats.html")

# %%
len(basketball_data)
# Out:
# 1

# %%
df = basketball_data[0]
df_clean = df.drop(df.index[[20, 21, 42, 43, 64, 65]])
df_clean.head()
# Out:
#   Rk   Season   Lg   Age   Ht   Wt     G     MP    FG   FGA  ...      PTS  \
# 0  1  2017-18  NBA  26.4  6-7  218  1230  241.4  39.6  86.1  ...    106.3
# 1  2  2016-17  NBA  26.6  6-7  220  1230  241.6  39.0  85.4  ...    105.6
# 2  3  2015-16  NBA  26.7  6-7  221  1230  241.8  38.2  84.6  ...    102.7
# 3  4  2014-15  NBA  26.7  6-7  222  1230  242.0  37.5  83.6  ...    100.0
# 4  5  2013-14  NBA  26.5  6-7  223  1230  242.0  37.7  83.0  ...    101.0
#
#     FG%   3P%   FT%  Pace  eFG%  TOV%  ORB% FT/FGA   ORtg
# 0  .460  .362  .767  97.3  .521  13.0  22.3   .193  108.6
# 1  .457  .358  .772  96.4  .514  12.7  23.3   .209  108.8
# 2  .452  .354  .757  95.8  .502  13.2  23.8   .209  106.4
# 3  .449  .350  .750  93.9  .496  13.3  25.1   .205  105.6
# 4  .454  .360  .756  93.9  .501  13.6  25.5   .215  106.6
#
# [5 rows x 32 columns]

# %%
df_clean['PTS'] = pd.to_numeric(df_clean['PTS'])
df_clean['FG'] = pd.to_numeric(df_clean['FG'])

# %%
points_24_second = df_clean.iloc[56:72, 22]
season_24_second = df_clean.iloc[56:72, 1]

# %%
points_24_second
# Out:
# 60    118.8
# 61    118.1
# 62    115.3
# 63    108.2
# 66    106.6
# 67     99.6
# 68     99.0
# 69     93.1
# 70     79.5
# 71     82.7
# 72     83.7
# 73     84.1
# 74     80.0
# 75     80.0
# 76     72.7
# 77     67.8
# Name: PTS, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.plot(season_24_second, points_24_second, 'go--', linewidth=2, markersize=12)
plt.title("Points Before and After 24 Second Shot Clock", fontsize=25)
plt.ylabel("Points", fontsize=20)
plt.xlabel("Season", fontsize=20)
plt.ylim((50,120))
plt.grid(True)
plt.vlines('1953-54', 0, 120)
plt.tick_params(labelsize = 12)

# %%
FG_24_second = df_clean.iloc[56:72, 8]
FG_24_second
# Out:
# 60    45.9
# 61    45.4
# 62    44.5
# 63    40.4
# 66    39.0
# 67    35.9
# 68    35.3
# 69    33.3
# 70    28.1
# 71    28.5
# 72    29.6
# 73    29.8
# 74    28.2
# 75    29.0
# 76    27.2
# 77    25.9
# Name: FG, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.plot(season_24_second, FG_24_second, 'go--', linewidth=2, markersize=12)
plt.title("FGs Before and After 24 Second Shot Clock", fontsize=25)
plt.ylabel("FGs", fontsize=20)
plt.xlabel("Season", fontsize=20)
plt.ylim((0,50))
plt.grid(True)
plt.vlines('1953-54', 0, 120)
plt.tick_params(labelsize = 12)
