# %%
import pandas as pd
import json 
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = os.path.join("draftcombinedrillresults2018.json")
with open(filepath) as jsonfile:
    nba_json = json.load(jsonfile)

nba_json
# Out:
# {'parameters': {'LeagueID': '00', 'SeasonYear': '2018-19'},
#  'resource': 'draftcombinedrillresults',
#  'resultSets': [{'headers': ['TEMP_PLAYER_ID',
#     'PLAYER_ID',
#     'FIRST_NAME',
#     'LAST_NAME',
#     'PLAYER_NAME',
#     'POSITION',
#     'STANDING_VERTICAL_LEAP',
#     'MAX_VERTICAL_LEAP',
#     'LANE_AGILITY_TIME',
#     'MODIFIED_LANE_AGILITY_TIME',
#     'THREE_QUARTER_SPRINT',
#     'BENCH_PRESS'],
#    'name': 'Results',
#    'rowSet': [[1628959,
#      1628959,
#      'Rawle',
#      'Alkins',
#      'Rawle Alkins',
#      'SG',
#      32.5,
#      40.5,
#      11.5,
#      3.09,
#      3.15,
#      10],
#     [1628960,
#      1628960,
#      'Grayson',
#      'Allen',
#      'Grayson Allen',
#      'SG',
#      32.5,
#      40.5,
#      10.31,
#      3.04,
#      3.15,
#      None],
#     [1628961,
#      1628961,
#      'Kostas',
#      'Antetokounmpo',
#      'Kostas Antetokounmpo',
#      'PF',
#      29.5,
#      35.0,
#      12.48,
#      3.48,
#      3.21,
#      0],
#     [1628962,
#      1628962,
#      'Udoka',
#      'Azubuike',
#      'Udoka Azubuike',
#      'C',
#      31.0,
#      31.5,
#      12.97,
#      3.65,
#      3.12,
#      11],
#     [1628964,
#      1628964,
#      'Mohamed',
#      'Bamba',
#      'Mohamed Bamba',
#      'C',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628965,
#      1628965,
#      'Jaylen',
#      'Barford',
#      'Jaylen Barford',
#      'PG-SG',
#      27.0,
#      33.0,
#      11.39,
#      3.21,
#      3.31,
#      7],
#     [1628966,
#      1628966,
#      'Keita',
#      'Bates-Diop',
#      'Keita Bates-Diop',
#      'SG-SF',
#      30.5,
#      35.0,
#      11.2,
#      3.28,
#      3.17,
#      11],
#     [1628967,
#      1628967,
#      'Tyus',
#      'Battle',
#      'Tyus Battle',
#      'SG',
#      32.0,
#      37.5,
#      11.04,
#      2.87,
#      3.07,
#      9],
#     [1628968,
#      1628968,
#      'Brian',
#      'Bowen',
#      'Brian Bowen',
#      'SG-SF',
#      30.5,
#      34.0,
#      11.58,
#      3.33,
#      3.28,
#      0],
#     [1628970,
#      1628970,
#      'Miles',
#      'Bridges',
#      'Miles Bridges',
#      'SF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628971,
#      1628971,
#      'Bruce',
#      'Brown',
#      'Bruce Brown',
#      'SG-PG',
#      32.5,
#      38.0,
#      11.11,
#      3.44,
#      3.2,
#      17],
#     [1628972,
#      1628972,
#      'Troy',
#      'Brown',
#      'Troy Brown',
#      'SF',
#      26.0,
#      33.0,
#      11.51,
#      3.29,
#      3.33,
#      5],
#     [1628973,
#      1628973,
#      'Jalen',
#      'Brunson',
#      'Jalen Brunson',
#      'PG',
#      29.0,
#      37.0,
#      10.59,
#      3.11,
#      3.15,
#      7],
#     [1628974,
#      1628974,
#      'Tony',
#      'Carr',
#      'Tony Carr',
#      'PG',
#      25.0,
#      31.5,
#      11.89,
#      3.4,
#      3.17,
#      0],
#     [1628976,
#      1628976,
#      'Wendell',
#      'Carter',
#      'Wendell Carter',
#      'C-PF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628975,
#      1628975,
#      'Jevon',
#      'Carter',
#      'Jevon Carter',
#      'PG',
#      29.0,
#      36.5,
#      11.04,
#      3.05,
#      3.18,
#      14],
#     [1628978,
#      1628978,
#      'Donte',
#      'DiVincenzo',
#      'Donte DiVincenzo',
#      'SG',
#      34.5,
#      42.0,
#      10.72,
#      3.12,
#      3.11,
#      12],
#     [1628977,
#      1628977,
#      'Hamidou',
#      'Diallo',
#      'Hamidou Diallo',
#      'SG',
#      32.5,
#      40.5,
#      10.53,
#      3.14,
#      3.1,
#      1],
#     [1628979,
#      1628979,
#      'Trevon',
#      'Duval',
#      'Trevon Duval',
#      'PG',
#      34.0,
#      41.5,
#      10.93,
#      3.09,
#      3.18,
#      6],
#     [1629035,
#      1629035,
#      'Carsen',
#      'Edwards',
#      'Carsen Edwards',
#      'PG',
#      28.5,
#      34.5,
#      11.59,
#      3.15,
#      3.2,
#      12],
#     [1628980,
#      1628980,
#      'Jacob',
#      'Evans',
#      'Jacob Evans',
#      'SG-SF',
#      28.0,
#      35.5,
#      11.11,
#      3.14,
#      3.2,
#      8],
#     [1629037,
#      1629037,
#      'Keenan',
#      'Evans',
#      'Keenan Evans',
#      'PG',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628981,
#      1628981,
#      'Bruno',
#      'Fernando',
#      'Bruno Fernando',
#      'C',
#      29.0,
#      35.0,
#      12.19,
#      3.03,
#      3.23,
#      11],
#     [1628982,
#      1628982,
#      'Melvin',
#      'Frazier',
#      'Melvin Frazier',
#      'SF-SG',
#      31.0,
#      40.5,
#      11.24,
#      3.08,
#      3.08,
#      0],
#     [1628983,
#      1628983,
#      'Shai',
#      'Gilgeous-Alexander',
#      'Shai Gilgeous-Alexander',
#      'PG',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628984,
#      1628984,
#      'Devonte',
#      'Graham',
#      'Devonte Graham',
#      'PG',
#      31.0,
#      37.0,
#      11.28,
#      3.15,
#      3.21,
#      14],
#     [1629036,
#      1629036,
#      'Isaac',
#      'Haas',
#      'Isaac Haas',
#      'C',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628985,
#      1628985,
#      'Devon',
#      'Hall',
#      'Devon Hall',
#      'SG',
#      25.0,
#      31.0,
#      10.95,
#      3.16,
#      3.27,
#      6],
#     [1628986,
#      1628986,
#      'Jaylen',
#      'Hands',
#      'Jaylen Hands',
#      'PG',
#      31.5,
#      39.5,
#      12.11,
#      3.16,
#      3.13,
#      6],
#     [1628987,
#      1628987,
#      'Kevin',
#      'Hervey',
#      'Kevin Hervey',
#      'PF',
#      27.5,
#      32.0,
#      11.28,
#      3.15,
#      3.36,
#      4],
#     [1628988,
#      1628988,
#      'Aaron',
#      'Holiday',
#      'Aaron Holiday',
#      'PG',
#      25.5,
#      33.0,
#      10.96,
#      3.22,
#      3.27,
#      None],
#     [1628989,
#      1628989,
#      'Kevin',
#      'Huerter',
#      'Kevin Huerter',
#      'SG',
#      31.0,
#      38.0,
#      10.89,
#      2.97,
#      3.09,
#      9],
#     [1628991,
#      1628991,
#      'Jaren',
#      'Jackson',
#      'Jaren Jackson',
#      'PF-C',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628992,
#      1628992,
#      'Justin',
#      'Jackson',
#      'Justin Jackson',
#      'PF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628993,
#      1628993,
#      'Alize',
#      'Johnson',
#      'Alize Johnson',
#      'PF',
#      25.0,
#      31.0,
#      11.83,
#      3.28,
#      3.38,
#      8],
#     [1628994,
#      1628994,
#      'George',
#      'King',
#      'George King',
#      'SF-SG',
#      31.0,
#      39.0,
#      10.75,
#      3.08,
#      3.29,
#      15],
#     [1628995,
#      1628995,
#      'Kevin',
#      'Knox',
#      'Kevin Knox',
#      'SF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1628996,
#      1628996,
#      'Sagaba',
#      'Konate',
#      'Sagaba Konate',
#      'C',
#      31.5,
#      35.0,
#      12.28,
#      3.36,
#      3.28,
#      12],
#     [1628997,
#      1628997,
#      'Caleb',
#      'Martin',
#      'Caleb Martin',
#      'SF-SG',
#      29.0,
#      36.5,
#      10.43,
#      2.75,
#      3.26,
#      6],
#     [1628998,
#      1628998,
#      'Cody',
#      'Martin',
#      'Cody Martin',
#      'SG-SF',
#      29.0,
#      36.5,
#      10.64,
#      3.05,
#      3.09,
#      4],
#     [1628999,
#      1628999,
#      'Yante',
#      'Maten',
#      'Yante Maten',
#      'PF-C',
#      27.0,
#      31.5,
#      11.35,
#      3.13,
#      3.17,
#      18],
#     [1629000,
#      1629000,
#      'Brandon',
#      'McCoy',
#      'Brandon McCoy',
#      'C',
#      27.5,
#      32.0,
#      11.77,
#      3.31,
#      3.23,
#      9],
#     [1629001,
#      1629001,
#      'DeAnthony',
#      'Melton',
#      'DeAnthony Melton',
#      'SG-PG',
#      31.0,
#      36.5,
#      11.48,
#      3.33,
#      3.23,
#      1],
#     [1629002,
#      1629002,
#      'Chimezie',
#      'Metu',
#      'Chimezie Metu',
#      'PF-C',
#      29.5,
#      36.0,
#      11.89,
#      3.25,
#      3.33,
#      5],
#     [1629003,
#      1629003,
#      'Shake',
#      'Milton',
#      'Shake Milton',
#      'SG-PG',
#      30.0,
#      33.0,
#      11.07,
#      3.19,
#      3.25,
#      2],
#     [1629004,
#      1629004,
#      'Sviatoslav',
#      'Mykhailiuk',
#      'Sviatoslav Mykhailiuk',
#      'SG-SF',
#      30.5,
#      37.0,
#      11.25,
#      3.18,
#      3.15,
#      4],
#     [1629005,
#      1629005,
#      'Malik',
#      'Newman',
#      'Malik Newman',
#      'SG',
#      27.5,
#      33.5,
#      10.9,
#      3.18,
#      3.13,
#      None],
#     [1629006,
#      1629006,
#      'Josh',
#      'Okogie',
#      'Josh Okogie',
#      'SG',
#      33.0,
#      42.0,
#      11.08,
#      3.03,
#      3.04,
#      12],
#     [1629033,
#      1629033,
#      'Theo',
#      'Pinson',
#      'Theo Pinson',
#      'SG-SF',
#      27.0,
#      34.0,
#      11.53,
#      3.11,
#      3.22,
#      7],
#     [1629007,
#      1629007,
#      'Jontay',
#      'Porter',
#      'Jontay Porter',
#      'C-PF',
#      25.5,
#      31.0,
#      11.9,
#      3.07,
#      3.4,
#      9],
#     [1629008,
#      1629008,
#      'Michael',
#      'Porter',
#      'Michael Porter',
#      'SF-PF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1629009,
#      1629009,
#      'Billy',
#      'Preston',
#      'Billy Preston',
#      'PF',
#      25.0,
#      33.0,
#      11.26,
#      3.35,
#      3.2,
#      0],
#     [1629010,
#      1629010,
#      'Jerome',
#      'Robinson',
#      'Jerome Robinson',
#      'SG',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1629012,
#      1629012,
#      'Collin',
#      'Sexton',
#      'Collin Sexton',
#      'PG',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [1629013,
#      1629013,
#      'Landry',
#      'Shamet',
#      'Landry Shamet',
#      'PG',
#      31.0,
#      39.5,
#      11.26,
#      3.21,
#      3.11,
#      8],
#     [1629014,
#      1629014,
#      'Anfernee',
#      'Simons',
#      'Anfernee Simons',
#      'SG-PG',
#      32.0,
#      41.5,
#      11.27,
#      3.16,
#      3.1,
#      1],
#     [1629015,
#      1629015,
#      'Zhaire',
#      'Smith',
#      'Zhaire Smith',
#      'SF-SG',
#      33.0,
#      41.5,
#      11.02,
#      3.15,
#      3.05,
#      10],
#     [1629034,
#      1629034,
#      'Ray',
#      'Spalding',
#      'Ray Spalding',
#      'PF',
#      26.0,
#      32.0,
#      11.48,
#      3.2,
#      3.34,
#      12],
#     [1629016,
#      1629016,
#      'Omari',
#      'Spellman',
#      'Omari Spellman',
#      'PF-C',
#      28.5,
#      35.5,
#      12.28,
#      3.35,
#      3.38,
#      8],
#     [1629017,
#      1629017,
#      'Khyri',
#      'Thomas',
#      'Khyri Thomas',
#      'SG',
#      30.0,
#      35.0,
#      10.96,
#      3.18,
#      3.18,
#      14],
#     [1629018,
#      1629018,
#      'Gary',
#      'Trent',
#      'Gary Trent',
#      'SG',
#      33.5,
#      39.5,
#      11.37,
#      2.99,
#      3.12,
#      12],
#     [1629019,
#      1629019,
#      'Allonzo',
#      'Trier',
#      'Allonzo Trier',
#      'SG',
#      32.0,
#      40.0,
#      11.02,
#      2.97,
#      3.14,
#      11],
#     [1629021,
#      1629021,
#      'Moritz',
#      'Wagner',
#      'Moritz Wagner',
#      'C-PF',
#      27.0,
#      34.0,
#      11.48,
#      3.07,
#      3.18,
#      8],
#     [1629022,
#      1629022,
#      'Lonnie',
#      'Walker',
#      'Lonnie Walker',
#      'SG',
#      31.5,
#      40.0,
#      10.87,
#      2.91,
#      3.06,
#      12],
#     [1629023,
#      1629023,
#      'PJ',
#      'Washington',
#      'PJ Washington',
#      'PF',
#      27.0,
#      34.0,
#      11.39,
#      3.43,
#      3.2,
#      3],
#     [1629024,
#      1629024,
#      'Austin',
#      'Wiley',
#      'Austin Wiley',
#      'C',
#      28.0,
#      33.5,
#      12.79,
#      3.27,
#      3.3,
#      14],
#     [1629025,
#      1629025,
#      'Kris',
#      'Wilkes',
#      'Kris Wilkes',
#      'SF',
#      28.0,
#      35.5,
#      11.29,
#      3.16,
#      3.24,
#      1],
#     [1629026,
#      1629026,
#      'Kenrich',
#      'Williams',
#      'Kenrich Williams',
#      'SF',
#      28.0,
#      33.0,
#      10.86,
#      3.28,
#      3.19,
#      14],
#     [1629027,
#      1629027,
#      'Trae',
#      'Young',
#      'Trae Young',
#      'PG',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None]]}]}

# %%
df = pd.DataFrame.from_dict(nba_json['resultSets'][0]['rowSet'], orient='columns')
table = df[[4, 5, 6, 7, 8, 9, 10, 11]]
table.columns = ['Name', 'Position', 'Standing Vertical(in)', 'Max Vertical(in)', 'Lane Agility(sec)', 'Mod Lane Agility(sec)', 'Three Quarter Sprint', 'Bench Press']
table
# Out:
#                        Name Position  Standing Vertical(in)  Max Vertical(in)  \
# 0              Rawle Alkins       SG                   32.5              40.5
# 1             Grayson Allen       SG                   32.5              40.5
# 2      Kostas Antetokounmpo       PF                   29.5              35.0
# 3            Udoka Azubuike        C                   31.0              31.5
# 4             Mohamed Bamba        C                    NaN               NaN
# 5            Jaylen Barford    PG-SG                   27.0              33.0
# 6          Keita Bates-Diop    SG-SF                   30.5              35.0
# 7               Tyus Battle       SG                   32.0              37.5
# 8               Brian Bowen    SG-SF                   30.5              34.0
# 9             Miles Bridges       SF                    NaN               NaN
# 10              Bruce Brown    SG-PG                   32.5              38.0
# 11               Troy Brown       SF                   26.0              33.0
# 12            Jalen Brunson       PG                   29.0              37.0
# 13                Tony Carr       PG                   25.0              31.5
# 14           Wendell Carter     C-PF                    NaN               NaN
# 15             Jevon Carter       PG                   29.0              36.5
# 16         Donte DiVincenzo       SG                   34.5              42.0
# 17           Hamidou Diallo       SG                   32.5              40.5
# 18             Trevon Duval       PG                   34.0              41.5
# 19           Carsen Edwards       PG                   28.5              34.5
# 20              Jacob Evans    SG-SF                   28.0              35.5
# 21             Keenan Evans       PG                    NaN               NaN
# 22           Bruno Fernando        C                   29.0              35.0
# 23           Melvin Frazier    SF-SG                   31.0              40.5
# 24  Shai Gilgeous-Alexander       PG                    NaN               NaN
# 25           Devonte Graham       PG                   31.0              37.0
# 26               Isaac Haas        C                    NaN               NaN
# 27               Devon Hall       SG                   25.0              31.0
# 28             Jaylen Hands       PG                   31.5              39.5
# 29             Kevin Hervey       PF                   27.5              32.0
# ..                      ...      ...                    ...               ...
# 39              Cody Martin    SG-SF                   29.0              36.5
# 40              Yante Maten     PF-C                   27.0              31.5
# 41            Brandon McCoy        C                   27.5              32.0
# 42         DeAnthony Melton    SG-PG                   31.0              36.5
# 43            Chimezie Metu     PF-C                   29.5              36.0
# 44             Shake Milton    SG-PG                   30.0              33.0
# 45    Sviatoslav Mykhailiuk    SG-SF                   30.5              37.0
# 46             Malik Newman       SG                   27.5              33.5
# 47              Josh Okogie       SG                   33.0              42.0
# 48              Theo Pinson    SG-SF                   27.0              34.0
# 49            Jontay Porter     C-PF                   25.5              31.0
# 50           Michael Porter    SF-PF                    NaN               NaN
# 51            Billy Preston       PF                   25.0              33.0
# 52          Jerome Robinson       SG                    NaN               NaN
# 53            Collin Sexton       PG                    NaN               NaN
# 54            Landry Shamet       PG                   31.0              39.5
# 55          Anfernee Simons    SG-PG                   32.0              41.5
# 56             Zhaire Smith    SF-SG                   33.0              41.5
# 57             Ray Spalding       PF                   26.0              32.0
# 58           Omari Spellman     PF-C                   28.5              35.5
# 59             Khyri Thomas       SG                   30.0              35.0
# 60               Gary Trent       SG                   33.5              39.5
# 61            Allonzo Trier       SG                   32.0              40.0
# 62            Moritz Wagner     C-PF                   27.0              34.0
# 63            Lonnie Walker       SG                   31.5              40.0
# 64            PJ Washington       PF                   27.0              34.0
# 65             Austin Wiley        C                   28.0              33.5
# 66              Kris Wilkes       SF                   28.0              35.5
# 67         Kenrich Williams       SF                   28.0              33.0
# 68               Trae Young       PG                    NaN               NaN
#
#     Lane Agility(sec)  Mod Lane Agility(sec)  Three Quarter Sprint  \
# 0               11.50                   3.09                  3.15
# 1               10.31                   3.04                  3.15
# 2               12.48                   3.48                  3.21
# 3               12.97                   3.65                  3.12
# 4                 NaN                    NaN                   NaN
# 5               11.39                   3.21                  3.31
# 6               11.20                   3.28                  3.17
# 7               11.04                   2.87                  3.07
# 8               11.58                   3.33                  3.28
# 9                 NaN                    NaN                   NaN
# 10              11.11                   3.44                  3.20
# 11              11.51                   3.29                  3.33
# 12              10.59                   3.11                  3.15
# 13              11.89                   3.40                  3.17
# 14                NaN                    NaN                   NaN
# 15              11.04                   3.05                  3.18
# 16              10.72                   3.12                  3.11
# 17              10.53                   3.14                  3.10
# 18              10.93                   3.09                  3.18
# 19              11.59                   3.15                  3.20
# 20              11.11                   3.14                  3.20
# 21                NaN                    NaN                   NaN
# 22              12.19                   3.03                  3.23
# 23              11.24                   3.08                  3.08
# 24                NaN                    NaN                   NaN
# 25              11.28                   3.15                  3.21
# 26                NaN                    NaN                   NaN
# 27              10.95                   3.16                  3.27
# 28              12.11                   3.16                  3.13
# 29              11.28                   3.15                  3.36
# ..                ...                    ...                   ...
# 39              10.64                   3.05                  3.09
# 40              11.35                   3.13                  3.17
# 41              11.77                   3.31                  3.23
# 42              11.48                   3.33                  3.23
# 43              11.89                   3.25                  3.33
# 44              11.07                   3.19                  3.25
# 45              11.25                   3.18                  3.15
# 46              10.90                   3.18                  3.13
# 47              11.08                   3.03                  3.04
# 48              11.53                   3.11                  3.22
# 49              11.90                   3.07                  3.40
# 50                NaN                    NaN                   NaN
# 51              11.26                   3.35                  3.20
# 52                NaN                    NaN                   NaN
# 53                NaN                    NaN                   NaN
# 54              11.26                   3.21                  3.11
# 55              11.27                   3.16                  3.10
# 56              11.02                   3.15                  3.05
# 57              11.48                   3.20                  3.34
# 58              12.28                   3.35                  3.38
# 59              10.96                   3.18                  3.18
# 60              11.37                   2.99                  3.12
# 61              11.02                   2.97                  3.14
# 62              11.48                   3.07                  3.18
# 63              10.87                   2.91                  3.06
# 64              11.39                   3.43                  3.20
# 65              12.79                   3.27                  3.30
# 66              11.29                   3.16                  3.24
# 67              10.86                   3.28                  3.19
# 68                NaN                    NaN                   NaN
#
#     Bench Press
# 0          10.0
# 1           NaN
# 2           0.0
# 3          11.0
# 4           NaN
# 5           7.0
# 6          11.0
# 7           9.0
# 8           0.0
# 9           NaN
# 10         17.0
# 11          5.0
# 12          7.0
# 13          0.0
# 14          NaN
# 15         14.0
# 16         12.0
# 17          1.0
# 18          6.0
# 19         12.0
# 20          8.0
# 21          NaN
# 22         11.0
# 23          0.0
# 24          NaN
# 25         14.0
# 26          NaN
# 27          6.0
# 28          6.0
# 29          4.0
# ..          ...
# 39          4.0
# 40         18.0
# 41          9.0
# 42          1.0
# 43          5.0
# 44          2.0
# 45          4.0
# 46          NaN
# 47         12.0
# 48          7.0
# 49          9.0
# 50          NaN
# 51          0.0
# 52          NaN
# 53          NaN
# 54          8.0
# 55          1.0
# 56         10.0
# 57         12.0
# 58          8.0
# 59         14.0
# 60         12.0
# 61         11.0
# 62          8.0
# 63         12.0
# 64          3.0
# 65         14.0
# 66          1.0
# 67         14.0
# 68          NaN
#
# [69 rows x 8 columns]

# %%
combine2018 = table.fillna(0)
combine2018.head()
# Out:
#                    Name Position  Standing Vertical(in)  Max Vertical(in)  \
# 0          Rawle Alkins       SG                   32.5              40.5
# 1         Grayson Allen       SG                   32.5              40.5
# 2  Kostas Antetokounmpo       PF                   29.5              35.0
# 3        Udoka Azubuike        C                   31.0              31.5
# 4         Mohamed Bamba        C                    0.0               0.0
#
#    Lane Agility(sec)  Mod Lane Agility(sec)  Three Quarter Sprint  Bench Press
# 0              11.50                   3.09                  3.15         10.0
# 1              10.31                   3.04                  3.15          0.0
# 2              12.48                   3.48                  3.21          0.0
# 3              12.97                   3.65                  3.12         11.0
# 4               0.00                   0.00                  0.00          0.0

# %%
combine2018.groupby("Position").count()
# Out:
#           Name  Standing Vertical(in)  Max Vertical(in)  Lane Agility(sec)  \
# Position
# C            7                      7                 7                  7
# C-PF         3                      3                 3                  3
# PF           7                      7                 7                  7
# PF-C         4                      4                 4                  4
# PG          13                     13                13                 13
# PG-SG        1                      1                 1                  1
# SF           5                      5                 5                  5
# SF-PF        1                      1                 1                  1
# SF-SG        4                      4                 4                  4
# SG          14                     14                14                 14
# SG-PG        4                      4                 4                  4
# SG-SF        6                      6                 6                  6
#
#           Mod Lane Agility(sec)  Three Quarter Sprint  Bench Press
# Position
# C                             7                     7            7
# C-PF                          3                     3            3
# PF                            7                     7            7
# PF-C                          4                     4            4
# PG                           13                    13           13
# PG-SG                         1                     1            1
# SF                            5                     5            5
# SF-PF                         1                     1            1
# SF-SG                         4                     4            4
# SG                           14                    14           14
# SG-PG                         4                     4            4
# SG-SF                         6                     6            6

# %%
combine2018['Position']=combine2018['Position'].replace(to_replace='C-PF', value='F-C')
combine2018['Position']=combine2018['Position'].replace(to_replace='PF-C', value='F-C')
combine2018['Position']=combine2018['Position'].replace(to_replace='SG-SF', value='F-G')
combine2018['Position']=combine2018['Position'].replace(to_replace='PG-SG', value='G')
combine2018['Position']=combine2018['Position'].replace(to_replace='SF-PF', value='F')
combine2018['Position']=combine2018['Position'].replace(to_replace='SF-SG', value='F-G')
combine2018['Position']=combine2018['Position'].replace(to_replace='SG-PG', value='G')

# %%
filepath2 = os.path.join("draftcombinedrillresults2008.json")
with open(filepath2) as jsonfile:
    nba_json2 = json.load(jsonfile)

nba_json2
# Out:
# {'parameters': {'LeagueID': '00', 'SeasonYear': '2007-08'},
#  'resource': 'draftcombinedrillresults',
#  'resultSets': [{'headers': ['TEMP_PLAYER_ID',
#     'PLAYER_ID',
#     'FIRST_NAME',
#     'LAST_NAME',
#     'PLAYER_NAME',
#     'POSITION',
#     'STANDING_VERTICAL_LEAP',
#     'MAX_VERTICAL_LEAP',
#     'LANE_AGILITY_TIME',
#     'MODIFIED_LANE_AGILITY_TIME',
#     'THREE_QUARTER_SPRINT',
#     'BENCH_PRESS'],
#    'name': 'Results',
#    'rowSet': [[None,
#      12204,
#      'Mohamed',
#      'Abukar',
#      'Mohamed Abukar',
#      'SF',
#      30.5,
#      35.0,
#      11.78,
#      None,
#      3.37,
#      15],
#     [None,
#      12205,
#      'Mario',
#      'Boggan',
#      'Mario Boggan',
#      'PF',
#      24.0,
#      26.5,
#      12.18,
#      None,
#      3.45,
#      12],
#     [None,
#      12206,
#      'Craig',
#      'Bradshaw',
#      'Craig Bradshaw',
#      'PF',
#      26.0,
#      28.0,
#      11.88,
#      None,
#      3.54,
#      12],
#     [None,
#      201147,
#      'Corey',
#      'Brewer',
#      'Corey Brewer',
#      'SF-SG',
#      30.5,
#      36.5,
#      11.69,
#      None,
#      3.22,
#      11],
#     [None,
#      201166,
#      'Aaron',
#      'Brooks',
#      'Aaron Brooks',
#      'PG',
#      32.5,
#      39.5,
#      10.57,
#      None,
#      3.2,
#      6],
#     [None,
#      201628,
#      'Bobby',
#      'Brown',
#      'Bobby Brown',
#      'PG',
#      32.5,
#      41.0,
#      11.27,
#      None,
#      3.25,
#      3],
#     [None,
#      201469,
#      'Russell',
#      'Carter',
#      'Russell Carter',
#      'SG',
#      33.0,
#      38.5,
#      11.61,
#      None,
#      3.29,
#      25],
#     [None,
#      12207,
#      'Coleman',
#      'Collins',
#      'Coleman Collins',
#      'PF',
#      30.0,
#      35.0,
#      11.47,
#      None,
#      None,
#      21],
#     [None,
#      201144,
#      'Mike',
#      'Conley',
#      'Mike Conley',
#      'PG',
#      35.5,
#      40.5,
#      11.63,
#      None,
#      3.09,
#      13],
#     [None,
#      201161,
#      'Daequan',
#      'Cook',
#      'Daequan Cook',
#      'SG',
#      30.0,
#      34.5,
#      11.12,
#      None,
#      3.22,
#      4],
#     [None,
#      12208,
#      'Ryvon',
#      'Covile',
#      'Ryvon Covile',
#      'C-PF',
#      25.0,
#      30.5,
#      12.52,
#      None,
#      3.37,
#      19],
#     [None,
#      201159,
#      'Javaris',
#      'Crittenton',
#      'Javaris Crittenton',
#      'PG',
#      32.5,
#      38.0,
#      11.6,
#      None,
#      3.32,
#      11],
#     [None,
#      201176,
#      'Jermareo',
#      'Davidson',
#      'Jermareo Davidson',
#      'PF',
#      27.0,
#      30.0,
#      12.63,
#      None,
#      3.53,
#      7],
#     [None,
#      12209,
#      'Justin',
#      'Doellman',
#      'Justin Doellman',
#      'PF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      19],
#     [None,
#      12210,
#      'Zabian',
#      'Dowdell',
#      'Zabian Dowdell',
#      'PG',
#      30.0,
#      33.5,
#      11.13,
#      None,
#      3.29,
#      3],
#     [None,
#      201162,
#      'Jared',
#      'Dudley',
#      'Jared Dudley',
#      'SF',
#      28.0,
#      32.0,
#      11.32,
#      None,
#      3.45,
#      14],
#     [None,
#      201142,
#      'Kevin',
#      'Durant',
#      'Kevin Durant',
#      'SF-PF',
#      26.0,
#      33.5,
#      12.33,
#      None,
#      3.45,
#      0],
#     [None,
#      12211,
#      'Rashaun',
#      'Freeman',
#      'Rashaun Freeman',
#      'PF',
#      28.0,
#      32.0,
#      11.43,
#      None,
#      3.41,
#      20],
#     [None,
#      201189,
#      'Aaron',
#      'Gray',
#      'Aaron Gray',
#      'C',
#      27.0,
#      32.5,
#      12.07,
#      None,
#      3.7,
#      17],
#     [None,
#      12212,
#      'Caleb',
#      'Green',
#      'Caleb Green',
#      'PF',
#      28.5,
#      36.0,
#      11.72,
#      None,
#      3.46,
#      9],
#     [None,
#      201145,
#      'Jeff',
#      'Green',
#      'Jeff Green',
#      'SF',
#      33.5,
#      38.0,
#      12.0,
#      None,
#      3.34,
#      17],
#     [None,
#      201192,
#      'Taurean',
#      'Green',
#      'Taurean Green',
#      'PG',
#      29.0,
#      32.5,
#      11.3,
#      None,
#      3.26,
#      8],
#     [None,
#      201150,
#      'Spencer',
#      'Hawes',
#      'Spencer Hawes',
#      'PF',
#      26.0,
#      29.0,
#      11.88,
#      None,
#      3.51,
#      9],
#     [None,
#      12214,
#      'Brandon',
#      'Heath',
#      'Brandon Heath',
#      'PG',
#      32.0,
#      36.0,
#      11.39,
#      None,
#      3.28,
#      11],
#     [None,
#      201195,
#      'Herbert',
#      'Hill',
#      'Herbert Hill',
#      'C',
#      30.5,
#      34.0,
#      12.31,
#      None,
#      3.39,
#      15],
#     [None,
#      201143,
#      'Al',
#      'Horford',
#      'Al Horford',
#      'PF',
#      31.0,
#      35.5,
#      12.15,
#      None,
#      3.37,
#      20],
#     [None,
#      12215,
#      'Quinton',
#      'Hosley',
#      'Quinton Hosley',
#      'SF-SG',
#      28.5,
#      34.0,
#      12.47,
#      None,
#      3.32,
#      12],
#     [None,
#      12216,
#      'James',
#      'Hughes',
#      'James Hughes',
#      'C',
#      31.0,
#      33.0,
#      13.31,
#      None,
#      3.37,
#      8],
#     [None,
#      12217,
#      'Jeremy',
#      'Hunt',
#      'Jeremy Hunt',
#      'SG',
#      30.5,
#      33.0,
#      12.11,
#      None,
#      3.29,
#      10],
#     [None,
#      12218,
#      'Ekene',
#      'Ibekwe',
#      'Ekene Ibekwe',
#      'PF',
#      34.5,
#      39.0,
#      11.0,
#      None,
#      3.28,
#      10],
#     [None,
#      12219,
#      'Dominic',
#      'James',
#      'Dominic James',
#      'PG',
#      33.5,
#      38.5,
#      10.94,
#      None,
#      3.11,
#      14],
#     [None,
#      201234,
#      'Trey',
#      'Johnson',
#      'Trey Johnson',
#      'SG',
#      26.5,
#      35.0,
#      11.78,
#      None,
#      3.31,
#      18],
#     [None,
#      12220,
#      'Rashad',
#      'Jones-Jennings',
#      'Rashad Jones-Jennings',
#      'PF',
#      25.0,
#      30.0,
#      12.18,
#      None,
#      3.29,
#      20],
#     [None,
#      201185,
#      'Jared',
#      'Jordan',
#      'Jared Jordan',
#      'PG',
#      24.5,
#      28.5,
#      11.02,
#      None,
#      3.39,
#      6],
#     [None,
#      201207,
#      'Coby',
#      'Karl',
#      'Coby Karl',
#      'SG-PG',
#      32.0,
#      34.5,
#      11.57,
#      None,
#      3.41,
#      9],
#     [None,
#      12221,
#      'Antanas',
#      'Kavaliauskas',
#      'Antanas Kavaliauskas',
#      'PF',
#      25.5,
#      30.0,
#      11.19,
#      None,
#      3.42,
#      19],
#     [None,
#      201171,
#      'Carl',
#      'Landry',
#      'Carl Landry',
#      'PF',
#      31.5,
#      36.5,
#      11.35,
#      None,
#      3.29,
#      21],
#     [None,
#      201186,
#      'Stephane',
#      'Lasme',
#      'Stephane Lasme',
#      'PF',
#      29.5,
#      36.0,
#      11.73,
#      None,
#      3.22,
#      17],
#     [None,
#      201151,
#      'Acie',
#      'Law',
#      'Acie Law',
#      'PG',
#      29.0,
#      34.0,
#      11.0,
#      None,
#      3.22,
#      8],
#     [None,
#      12222,
#      'Marko',
#      'Lekic',
#      'Marko Lekic',
#      'C',
#      24.0,
#      30.5,
#      11.96,
#      None,
#      3.43,
#      19],
#     [None,
#      12223,
#      'Ron',
#      'Lewis',
#      'Ron Lewis',
#      'SG',
#      33.0,
#      38.0,
#      11.59,
#      None,
#      3.22,
#      16],
#     [None,
#      201858,
#      'Cartier',
#      'Martin',
#      'Cartier Martin',
#      'SF',
#      27.0,
#      29.5,
#      12.1,
#      None,
#      3.43,
#      11],
#     [None,
#      201187,
#      'Dominic',
#      'McGuire',
#      'Dominic McGuire',
#      'SF',
#      28.5,
#      34.5,
#      10.95,
#      None,
#      3.25,
#      12],
#     [None,
#      201177,
#      'Josh',
#      'McRoberts',
#      'Josh McRoberts',
#      'PF',
#      27.5,
#      31.5,
#      11.7,
#      None,
#      3.47,
#      12],
#     [None,
#      201197,
#      'Sammy',
#      'Mejia',
#      'Sammy Mejia',
#      'SG',
#      27.0,
#      31.5,
#      11.87,
#      None,
#      3.49,
#      7],
#     [None,
#      12224,
#      'Brad',
#      'Newley',
#      'Brad Newley',
#      'SG',
#      29.5,
#      31.5,
#      11.77,
#      None,
#      3.29,
#      3],
#     [None,
#      201193,
#      'Demetris',
#      'Nichols',
#      'Demetris Nichols',
#      'SF',
#      28.5,
#      32.5,
#      10.39,
#      None,
#      3.38,
#      16],
#     [None,
#      201149,
#      'Joakim',
#      'Noah',
#      'Joakim Noah',
#      'PF',
#      32.5,
#      37.5,
#      11.79,
#      None,
#      3.47,
#      12],
#     [None,
#      201141,
#      'Greg',
#      'Oden',
#      'Greg Oden',
#      'C',
#      32.0,
#      34.0,
#      11.67,
#      None,
#      3.27,
#      None],
#     [None,
#      12225,
#      'Ivan',
#      'Radenovic',
#      'Ivan Radenovic',
#      'PF',
#      23.0,
#      28.0,
#      11.61,
#      None,
#      3.6,
#      7],
#     [None,
#      12226,
#      'JR',
#      'Reynolds',
#      'JR Reynolds',
#      'PG',
#      27.5,
#      34.5,
#      11.69,
#      None,
#      3.24,
#      15],
#     [None,
#      201181,
#      'Chris',
#      'Richard',
#      'Chris Richard',
#      'PF',
#      26.5,
#      30.5,
#      11.39,
#      None,
#      3.29,
#      15],
#     [None,
#      12227,
#      'Dustin',
#      'Salisbery',
#      'Dustin Salisbery',
#      'SG',
#      34.0,
#      38.0,
#      11.07,
#      None,
#      3.12,
#      11],
#     [None,
#      12228,
#      'Blake',
#      'Schilb',
#      'Blake Schilb',
#      'SG',
#      26.5,
#      33.5,
#      11.63,
#      None,
#      3.36,
#      11],
#     [None,
#      12229,
#      'Renaldas',
#      'Seibutis',
#      'Renaldas Seibutis',
#      'SG',
#      24.0,
#      32.5,
#      11.33,
#      None,
#      3.39,
#      1],
#     [None,
#      201196,
#      'Ramon',
#      'Sessions',
#      'Ramon Sessions',
#      'PG',
#      29.5,
#      33.5,
#      11.65,
#      None,
#      3.27,
#      8],
#     [None,
#      201203,
#      'Mustafa',
#      'Shakur',
#      'Mustafa Shakur',
#      'PG',
#      28.5,
#      35.0,
#      11.82,
#      None,
#      3.27,
#      11],
#     [None,
#      201160,
#      'Jason',
#      'Smith',
#      'Jason Smith',
#      'PF',
#      33.5,
#      37.5,
#      10.96,
#      None,
#      3.29,
#      15],
#     [None,
#      201199,
#      'DJ',
#      'Strawberry',
#      'DJ Strawberry',
#      'SG',
#      28.5,
#      35.0,
#      10.87,
#      None,
#      3.14,
#      21],
#     [None,
#      201155,
#      'Rodney',
#      'Stuckey',
#      'Rodney Stuckey',
#      'SG-PG',
#      30.5,
#      35.0,
#      11.34,
#      None,
#      3.11,
#      14],
#     [None,
#      12230,
#      'Curtis',
#      'Sumpter',
#      'Curtis Sumpter',
#      'SF',
#      27.5,
#      32.5,
#      11.3,
#      None,
#      3.22,
#      12],
#     [None,
#      201180,
#      'Yue',
#      'Sun',
#      'Yue Sun',
#      'SF',
#      29.0,
#      34.0,
#      10.68,
#      None,
#      3.45,
#      9],
#     [None,
#      201249,
#      'Jamaal',
#      'Tatum',
#      'Jamaal Tatum',
#      'PG',
#      28.5,
#      33.0,
#      11.51,
#      None,
#      3.22,
#      7],
#     [None,
#      12232,
#      'Reyshawn',
#      'Terry',
#      'Reyshawn Terry',
#      'SF',
#      31.0,
#      37.5,
#      11.76,
#      None,
#      3.26,
#      18],
#     [None,
#      201154,
#      'Al',
#      'Thornton',
#      'Al Thornton',
#      'SF',
#      35.0,
#      41.0,
#      11.96,
#      None,
#      3.16,
#      9],
#     [None,
#      201229,
#      'Anthony',
#      'Tolliver',
#      'Anthony Tolliver',
#      'PF',
#      28.5,
#      30.0,
#      11.49,
#      None,
#      3.29,
#      21],
#     [None,
#      12233,
#      'Ali',
#      'Traore',
#      'Ali Traore',
#      'C-PF',
#      25.0,
#      29.0,
#      12.16,
#      None,
#      3.52,
#      11],
#     [None,
#      12234,
#      'Kyle',
#      'Visser',
#      'Kyle Visser',
#      'C',
#      26.0,
#      29.0,
#      12.6,
#      None,
#      3.39,
#      18],
#     [None,
#      201208,
#      'Darryl',
#      'Watkins',
#      'Darryl Watkins',
#      'C',
#      26.5,
#      31.0,
#      11.65,
#      None,
#      3.56,
#      14],
#     [None,
#      12235,
#      'Major',
#      'Wingate',
#      'Major Wingate',
#      'C',
#      27.5,
#      30.5,
#      12.14,
#      None,
#      3.47,
#      15],
#     [None,
#      12236,
#      'DaShaun',
#      'Wood',
#      'DaShaun Wood',
#      'PG',
#      31.5,
#      34.5,
#      11.4,
#      None,
#      3.23,
#      13],
#     [None,
#      201148,
#      'Brandan',
#      'Wright',
#      'Brandan Wright',
#      'PF',
#      30.5,
#      35.5,
#      11.76,
#      None,
#      3.31,
#      2],
#     [None,
#      201153,
#      'Julian',
#      'Wright',
#      'Julian Wright',
#      'SF-PF',
#      28.5,
#      33.5,
#      11.48,
#      None,
#      3.36,
#      2],
#     [None,
#      12237,
#      'Avis',
#      'Wyatt',
#      'Avis Wyatt',
#      'PF',
#      27.5,
#      32.0,
#      11.46,
#      None,
#      3.23,
#      12],
#     [None,
#      201146,
#      'Jianlian',
#      'Yi',
#      'Jianlian Yi',
#      '',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [None,
#      201156,
#      'Nick',
#      'Young',
#      'Nick Young',
#      'SG-SF',
#      39.5,
#      40.5,
#      11.0,
#      None,
#      3.25,
#      6],
#     [None,
#      201152,
#      'Thaddeus',
#      'Young',
#      'Thaddeus Young',
#      'SF',
#      34.5,
#      37.0,
#      11.06,
#      None,
#      3.19,
#      13]]}]}

# %%
df2 = pd.DataFrame.from_dict(nba_json2['resultSets'][0]['rowSet'], orient='columns')
table2 = df2[[4, 5, 6, 7, 8, 9, 10, 11]]
table2.columns = ['Name', 'Position', 'Standing Vertical(in)', 'Max Vertical(in)', 'Lane Agility(sec)', 'Mod Lane Agility(sec)', 'Three Quarter Sprint', 'Bench Press']
table2.head()
# Out:
#              Name Position  Standing Vertical(in)  Max Vertical(in)  \
# 0  Mohamed Abukar       SF                   30.5              35.0
# 1    Mario Boggan       PF                   24.0              26.5
# 2  Craig Bradshaw       PF                   26.0              28.0
# 3    Corey Brewer    SF-SG                   30.5              36.5
# 4    Aaron Brooks       PG                   32.5              39.5
#
#    Lane Agility(sec) Mod Lane Agility(sec)  Three Quarter Sprint  Bench Press
# 0              11.78                  None                  3.37         15.0
# 1              12.18                  None                  3.45         12.0
# 2              11.88                  None                  3.54         12.0
# 3              11.69                  None                  3.22         11.0
# 4              10.57                  None                  3.20          6.0

# %%
combine2008 = table2.fillna(0)
combine2008.head()
# Out:
#              Name Position  Standing Vertical(in)  Max Vertical(in)  \
# 0  Mohamed Abukar       SF                   30.5              35.0
# 1    Mario Boggan       PF                   24.0              26.5
# 2  Craig Bradshaw       PF                   26.0              28.0
# 3    Corey Brewer    SF-SG                   30.5              36.5
# 4    Aaron Brooks       PG                   32.5              39.5
#
#    Lane Agility(sec)  Mod Lane Agility(sec)  Three Quarter Sprint  Bench Press
# 0              11.78                      0                  3.37         15.0
# 1              12.18                      0                  3.45         12.0
# 2              11.88                      0                  3.54         12.0
# 3              11.69                      0                  3.22         11.0
# 4              10.57                      0                  3.20          6.0

# %%
combine2008['Position']=combine2008['Position'].replace(to_replace='C-PF', value='F-C')
combine2008['Position']=combine2008['Position'].replace(to_replace='PF-C', value='F-C')
combine2008['Position']=combine2008['Position'].replace(to_replace='SG-SF', value='F-G')
combine2008['Position']=combine2008['Position'].replace(to_replace='PG-SG', value='G')
combine2008['Position']=combine2008['Position'].replace(to_replace='SF-PF', value='F')
combine2008['Position']=combine2008['Position'].replace(to_replace='SF-SG', value='F-G')
combine2008['Position']=combine2008['Position'].replace(to_replace='SG-PG', value='G')

# %%
combine18 = combine2018.groupby("Position").mean()
vert18 = combine18[["Standing Vertical(in)", "Max Vertical(in)"]]
vert18.columns = [["Standing Vertical 2018", "Max Vertical 2018"]]
vert18
# Out:
#          Standing Vertical 2018 Max Vertical 2018
# Position
# C                     21.000000         23.857143
# F                      0.000000          0.000000
# F-C                   19.642857         24.000000
# F-G                   29.950000         36.950000
# G                     30.500000         36.400000
# PF                    22.857143         28.142857
# PG                    20.346154         25.384615
# SF                    16.400000         20.300000
# SG                    29.107143         35.714286

# %%
combine08 = combine2008.groupby("Position").mean()
vert08 = combine08[["Standing Vertical(in)", "Max Vertical(in)"]]
vert08.columns = [["Standing Vertical 2008", "Max Vertical 2008"]]
vert08
# Out:
#          Standing Vertical 2008 Max Vertical 2008
# Position
#                        0.000000          0.000000
# C                     28.062500         31.812500
# F                     27.250000         33.500000
# F-C                   25.000000         29.750000
# F-G                   32.833333         37.000000
# G                     31.250000         34.750000
# PF                    27.090909         31.181818
# PG                    30.433333         35.500000
# SF                    30.272727         34.863636
# SG                    29.318182         34.636364

# %%
vert08.drop(vert08.index[0])
# Out:
#          Standing Vertical 2008 Max Vertical 2008
# Position
# C                     28.062500         31.812500
# F                     27.250000         33.500000
# F-C                   25.000000         29.750000
# F-G                   32.833333         37.000000
# G                     31.250000         34.750000
# PF                    27.090909         31.181818
# PG                    30.433333         35.500000
# SF                    30.272727         34.863636
# SG                    29.318182         34.636364

# %%
filepath3 = os.path.join("draftcombinedrillresults2000.json")
with open(filepath3) as jsonfile:
    nba_json3 = json.load(jsonfile)

nba_json3
# Out:
# {'parameters': {'LeagueID': '00', 'SeasonYear': '2000-01'},
#  'resource': 'draftcombinedrillresults',
#  'resultSets': [{'headers': ['TEMP_PLAYER_ID',
#     'PLAYER_ID',
#     'FIRST_NAME',
#     'LAST_NAME',
#     'PLAYER_NAME',
#     'POSITION',
#     'STANDING_VERTICAL_LEAP',
#     'MAX_VERTICAL_LEAP',
#     'LANE_AGILITY_TIME',
#     'MODIFIED_LANE_AGILITY_TIME',
#     'THREE_QUARTER_SPRINT',
#     'BENCH_PRESS'],
#    'name': 'Results',
#    'rowSet': [[None,
#      2124,
#      'Malik',
#      'Allen',
#      'Malik Allen',
#      'PF-C',
#      25.5,
#      29.0,
#      11.83,
#      None,
#      3.38,
#      13],
#     [None,
#      12019,
#      'Harold',
#      'Arceneaux',
#      'Harold Arceneaux',
#      'SG-SF',
#      None,
#      29.0,
#      13.8,
#      None,
#      None,
#      0],
#     [None,
#      12020,
#      'Lamont',
#      'Barnes',
#      'Lamont Barnes',
#      'PF-C',
#      28.0,
#      29.5,
#      12.3,
#      None,
#      3.4,
#      10],
#     [None,
#      12131,
#      'Mario',
#      'Bland',
#      'Mario Bland',
#      'PF',
#      27.0,
#      31.0,
#      13.04,
#      None,
#      3.47,
#      15],
#     [None,
#      2056,
#      'Primoz',
#      'Brezec',
#      'Primoz Brezec',
#      'C',
#      26.0,
#      29.5,
#      11.53,
#      None,
#      3.55,
#      None],
#     [None,
#      2081,
#      'Ernest',
#      'Brown',
#      'Ernest Brown',
#      'C',
#      None,
#      None,
#      None,
#      None,
#      None,
#      2],
#     [None,
#      2049,
#      'Speedy',
#      'Claxton',
#      'Speedy Claxton',
#      'PG',
#      36.0,
#      42.5,
#      10.48,
#      None,
#      3.06,
#      6],
#     [None,
#      12132,
#      'Eric',
#      'Coley',
#      'Eric Coley',
#      'SG-SF',
#      35.0,
#      38.0,
#      11.4,
#      None,
#      3.15,
#      10],
#     [None,
#      12133,
#      'Ed',
#      'Cota',
#      'Ed Cota',
#      'PG',
#      26.5,
#      33.5,
#      10.98,
#      None,
#      3.24,
#      1],
#     [None,
#      12134,
#      'Schea',
#      'Cotton',
#      'Schea Cotton',
#      'SF',
#      34.0,
#      38.0,
#      11.55,
#      None,
#      3.0,
#      19],
#     [None,
#      2037,
#      'Jamal',
#      'Crawford',
#      'Jamal Crawford',
#      'PG-SG',
#      None,
#      None,
#      None,
#      None,
#      None,
#      0],
#     [None,
#      12017,
#      'Caswell',
#      'Cyrus',
#      'Caswell Cyrus',
#      'PF',
#      33.5,
#      37.5,
#      12.12,
#      None,
#      3.16,
#      18],
#     [None,
#      2064,
#      'Khalid',
#      'El-Amin',
#      'Khalid El-Amin',
#      'PG',
#      27.5,
#      32.0,
#      10.59,
#      None,
#      3.32,
#      6],
#     [None,
#      12018,
#      'Vassil',
#      'Evtimov',
#      'Vassil Evtimov',
#      'PF',
#      21.0,
#      28.5,
#      11.75,
#      None,
#      3.52,
#      13],
#     [None,
#      2238,
#      'Antonis',
#      'Fotsis',
#      'Antonis Fotsis',
#      'SF',
#      27.0,
#      30.0,
#      11.6,
#      None,
#      3.44,
#      2],
#     [None,
#      2109,
#      'Eddie',
#      'Gill',
#      'Eddie Gill',
#      'PG',
#      35.0,
#      38.5,
#      11.12,
#      None,
#      3.18,
#      13],
#     [None,
#      12135,
#      'Ceedric',
#      'Goodwyn',
#      'Ceedric Goodwyn',
#      'SF-PF',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     [None,
#      12136,
#      'Marcus',
#      'Goree',
#      'Marcus Goree',
#      'SF-PF',
#      29.5,
#      33.5,
#      12.0,
#      None,
#      3.25,
#      13],
#     [None,
#      12137,
#      'A.J.',
#      'Granger',
#      'A.J. Granger',
#      'SF',
#      30.0,
#      34.0,
#      10.73,
#      None,
#      3.25,
#      20],
#     [None,
#      2062,
#      'A.J.',
#      'Guyton',
#      'A.J. Guyton',
#      'PG-SG',
#      33.0,
#      37.5,
#      10.55,
#      None,
#      3.22,
#      9],
#     [None,
#      2110,
#      'Ron',
#      'Hale',
#      'Ron Hale',
#      'SG-SF',
#      29.5,
#      34.5,
#      12.58,
#      None,
#      3.2,
#      11],
#     [None,
#      2078,
#      'Jason',
#      'Hart',
#      'Jason Hart',
#      'PG',
#      29.5,
#      33.5,
#      11.7,
#      None,
#      3.34,
#      9],
#     [None,
#      2051,
#      'Donnell',
#      'Harvey',
#      'Donnell Harvey',
#      'PF',
#      33.0,
#      32.5,
#      11.23,
#      None,
#      None,
#      15],
#     [None,
#      12138,
#      'Johnny',
#      'Hemsley',
#      'Johnny Hemsley',
#      'SG-SF',
#      31.5,
#      35.0,
#      11.5,
#      None,
#      3.19,
#      5],
#     [None,
#      12139,
#      'Michael',
#      'Hermon',
#      'Michael Hermon',
#      'SG-PG',
#      29.0,
#      33.0,
#      11.79,
#      None,
#      3.25,
#      0],
#     [None,
#      2083,
#      'Cory',
#      'Hightower',
#      'Cory Hightower',
#      'SG-SF',
#      29.5,
#      34.5,
#      11.92,
#      None,
#      3.37,
#      0],
#     [None,
#      12140,
#      'Shaheen',
#      'Holloway',
#      'Shaheen Holloway',
#      'PG',
#      None,
#      None,
#      11.22,
#      None,
#      3.32,
#      6],
#     [None,
#      2067,
#      'Eddie',
#      'House',
#      'Eddie House',
#      'SG-PG',
#      29.5,
#      38.5,
#      11.12,
#      None,
#      3.27,
#      5],
#     [None,
#      2111,
#      'Jimmie',
#      'Hunter',
#      'Jimmie Hunter',
#      'SG-PG',
#      29.0,
#      36.0,
#      11.23,
#      None,
#      3.35,
#      0],
#     [None,
#      12141,
#      'Jacob',
#      'Jaacks',
#      'Jacob Jaacks',
#      'PF',
#      26.0,
#      32.0,
#      11.48,
#      None,
#      3.58,
#      3],
#     [None,
#      2060,
#      'Marko',
#      'Jaric',
#      'Marko Jaric',
#      'SG-SF',
#      27.5,
#      33.0,
#      11.32,
#      None,
#      3.28,
#      None],
#     [None,
#      12142,
#      'Nate',
#      'Johnson',
#      'Nate Johnson',
#      'SF',
#      27.0,
#      33.5,
#      11.9,
#      None,
#      3.33,
#      13],
#     [None,
#      12143,
#      'Kenyon',
#      'Jones',
#      'Kenyon Jones',
#      'PF-C',
#      28.5,
#      30.0,
#      12.44,
#      None,
#      3.6,
#      20],
#     [None,
#      2077,
#      'Mark',
#      'Karcher',
#      'Mark Karcher',
#      'SG',
#      27.5,
#      30.5,
#      11.51,
#      None,
#      3.4,
#      12],
#     [None,
#      12144,
#      'Brandon',
#      'Kurtz',
#      'Brandon Kurtz',
#      'PF-C',
#      None,
#      None,
#      None,
#      None,
#      None,
#      7],
#     [None,
#      2061,
#      'Dan',
#      'Langhi',
#      'Dan Langhi',
#      'SF',
#      31.0,
#      34.5,
#      10.85,
#      None,
#      3.24,
#      12],
#     [None,
#      2090,
#      'Justin',
#      'Love',
#      'Justin Love',
#      'PG-SG',
#      31.0,
#      38.5,
#      10.99,
#      None,
#      3.31,
#      24],
#     [None,
#      2058,
#      'Mark',
#      'Madsen',
#      'Mark Madsen',
#      'PF',
#      30.5,
#      33.5,
#      12.12,
#      None,
#      3.46,
#      13],
#     [None,
#      2082,
#      'Dan',
#      'McClintock',
#      'Dan McClintock',
#      'C-PF',
#      33.0,
#      35.0,
#      11.52,
#      None,
#      3.33,
#      20],
#     [None,
#      2087,
#      'Pete',
#      'Mickeal',
#      'Pete Mickeal',
#      'SG-SF',
#      28.0,
#      34.5,
#      10.83,
#      None,
#      3.06,
#      8],
#     [None,
#      12145,
#      'Brian',
#      'Montonati',
#      'Brian Montonati',
#      'PF',
#      25.0,
#      29.0,
#      11.85,
#      None,
#      3.53,
#      5],
#     [None,
#      2508,
#      'Gabe',
#      'Muoneke',
#      'Gabe Muoneke',
#      'PF-SF',
#      30.5,
#      34.0,
#      11.0,
#      None,
#      3.4,
#      22],
#     [None,
#      12146,
#      'Ndongo',
#      "N'diaye",
#      "Ndongo N'diaye",
#      'C',
#      24.5,
#      27.5,
#      13.16,
#      None,
#      3.69,
#      4],
#     [None,
#      2059,
#      'Eduardo',
#      'Najera',
#      'Eduardo Najera',
#      'PF-SF',
#      28.0,
#      35.0,
#      11.38,
#      None,
#      3.45,
#      15],
#     [None,
#      12147,
#      'Matthew',
#      'Nielsen',
#      'Matthew Nielsen',
#      'PF',
#      26.0,
#      29.0,
#      11.28,
#      None,
#      3.35,
#      3],
#     [None,
#      2084,
#      'Chris',
#      'Porter',
#      'Chris Porter',
#      'SF-PF',
#      28.5,
#      35.0,
#      10.93,
#      None,
#      3.2,
#      6],
#     [None,
#      2068,
#      'Lavor',
#      'Postell',
#      'Lavor Postell',
#      'SG',
#      33.5,
#      36.5,
#      11.79,
#      None,
#      3.3,
#      17],
#     [None,
#      2080,
#      'Igor',
#      'Rakocevic',
#      'Igor Rakocevic',
#      'PG',
#      27.5,
#      34.0,
#      10.4,
#      None,
#      3.1,
#      9],
#     [None,
#      12148,
#      'Reed',
#      'Rawlings',
#      'Reed Rawlings',
#      'SG-SF',
#      28.5,
#      33.5,
#      11.1,
#      None,
#      3.27,
#      13],
#     [None,
#      2072,
#      'Michael',
#      'Redd',
#      'Michael Redd',
#      'SG-SF',
#      27.0,
#      31.0,
#      12.06,
#      None,
#      3.34,
#      12],
#     [None,
#      12149,
#      'Damon',
#      'Reed',
#      'Damon Reed',
#      'PF-C',
#      27.5,
#      31.5,
#      11.21,
#      None,
#      3.31,
#      4],
#     [None,
#      12021,
#      'Aubrey',
#      'Reese',
#      'Aubrey Reese',
#      'PG',
#      31.5,
#      37.5,
#      11.13,
#      None,
#      3.25,
#      14],
#     [None,
#      2121,
#      'Terrance',
#      'Roberson',
#      'Terrance Roberson',
#      'SF',
#      29.0,
#      32.5,
#      11.66,
#      None,
#      None,
#      11],
#     [None,
#      12022,
#      'Julius Doc',
#      'Robinson',
#      'Julius Doc Robinson',
#      'PG',
#      30.0,
#      37.5,
#      12.54,
#      None,
#      3.41,
#      0],
#     [None,
#      12023,
#      'Pepe',
#      'Sanchez',
#      'Pepe Sanchez',
#      'PG',
#      26.0,
#      31.0,
#      11.62,
#      None,
#      3.44,
#      8],
#     [None,
#      12024,
#      'Matt',
#      'Santangelo',
#      'Matt Santangelo',
#      'PG',
#      33.5,
#      43.0,
#      10.66,
#      None,
#      3.06,
#      12],
#     [None,
#      2637,
#      'Alex',
#      'Scales',
#      'Alex Scales',
#      'SG-PG',
#      38.5,
#      42.5,
#      10.98,
#      None,
#      3.21,
#      10],
#     [None,
#      12025,
#      'Karim',
#      'Shabazz',
#      'Karim Shabazz',
#      'C',
#      24.5,
#      28.0,
#      12.72,
#      None,
#      3.36,
#      2],
#     [None,
#      12026,
#      'Nick',
#      'Sheppard',
#      'Nick Sheppard',
#      'PF-C',
#      23.5,
#      25.5,
#      12.14,
#      None,
#      3.52,
#      18],
#     [None,
#      2074,
#      'Jabari',
#      'Smith',
#      'Jabari Smith',
#      'PF-C',
#      24.5,
#      30.0,
#      12.45,
#      None,
#      3.43,
#      15],
#     [None,
#      2065,
#      'Mike',
#      'Smith',
#      'Mike Smith',
#      'SF',
#      33.0,
#      21.0,
#      11.32,
#      None,
#      3.22,
#      12],
#     [None,
#      12027,
#      'Jarrett',
#      'Stephens',
#      'Jarrett Stephens',
#      'PF',
#      27.0,
#      29.0,
#      11.98,
#      None,
#      3.46,
#      13],
#     [None,
#      12028,
#      'Bootsy',
#      'Thornton',
#      'Bootsy Thornton',
#      'SG',
#      26.5,
#      31.0,
#      12.08,
#      None,
#      3.33,
#      7],
#     [None,
#      12029,
#      'Jaquay',
#      'Walls',
#      'Jaquay Walls',
#      'PG',
#      28.5,
#      35.5,
#      10.75,
#      None,
#      3.23,
#      0],
#     [None,
#      12030,
#      'Jameel',
#      'Watkins',
#      'Jameel Watkins',
#      'PF-C',
#      28.0,
#      30.5,
#      12.38,
#      None,
#      3.45,
#      11]]}]}

# %%
df3 = pd.DataFrame.from_dict(nba_json3['resultSets'][0]['rowSet'], orient='columns')
table3 = df3[[4, 5, 6, 7, 8, 10, 11]]
table3.columns = ['Name', 'Position', 'Standing Vertical(in)', 'Max Vertical(in)', 'Lane Agility(sec)', 'Three Quarter Sprint', 'Bench Press']
table3.head()
# Out:
#                Name Position  Standing Vertical(in)  Max Vertical(in)  \
# 0       Malik Allen     PF-C                   25.5              29.0
# 1  Harold Arceneaux    SG-SF                    NaN              29.0
# 2     Lamont Barnes     PF-C                   28.0              29.5
# 3       Mario Bland       PF                   27.0              31.0
# 4     Primoz Brezec        C                   26.0              29.5
#
#    Lane Agility(sec)  Three Quarter Sprint  Bench Press
# 0              11.83                  3.38         13.0
# 1              13.80                   NaN          0.0
# 2              12.30                  3.40         10.0
# 3              13.04                  3.47         15.0
# 4              11.53                  3.55          NaN

# %%
combine2000 = table3.fillna(0)
combine2000.head()
# Out:
#                Name Position  Standing Vertical(in)  Max Vertical(in)  \
# 0       Malik Allen     PF-C                   25.5              29.0
# 1  Harold Arceneaux    SG-SF                    0.0              29.0
# 2     Lamont Barnes     PF-C                   28.0              29.5
# 3       Mario Bland       PF                   27.0              31.0
# 4     Primoz Brezec        C                   26.0              29.5
#
#    Lane Agility(sec)  Three Quarter Sprint  Bench Press
# 0              11.83                  3.38         13.0
# 1              13.80                  0.00          0.0
# 2              12.30                  3.40         10.0
# 3              13.04                  3.47         15.0
# 4              11.53                  3.55          0.0

# %%
combine2000['Position']=combine2000['Position'].replace(to_replace='C-PF', value='F-C')
combine2000['Position']=combine2000['Position'].replace(to_replace='PF-C', value='F-C')
combine2000['Position']=combine2000['Position'].replace(to_replace='SG-SF', value='F-G')
combine2000['Position']=combine2000['Position'].replace(to_replace='PG-SG', value='G')
combine2000['Position']=combine2000['Position'].replace(to_replace='SF-PF', value='F')
combine2000['Position']=combine2000['Position'].replace(to_replace='SF-SG', value='F-G')
combine2000['Position']=combine2000['Position'].replace(to_replace='SG-PG', value='G')

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2018["Position"], combine2018["Max Vertical(in)"], c='red', alpha=0.5)
plt.ylim(30,45)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Max Vertical(in)', fontsize=15)
plt.title('Maximum Vertical for 2018 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2018["Position"], combine2018["Lane Agility(sec)"], c='blue', alpha=0.5)
plt.ylim(10,13.5)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Lane Agility (sec)', fontsize=15)
plt.title('Lane Agility for 2018 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2018["Position"], combine2018["Three Quarter Sprint"], c='green', alpha=0.5)
plt.ylim(3,3.5)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Three Quarter Sprint (sec)', fontsize=15)
plt.title('Three Quarter Sprint (sec) for 2018 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2018["Position"], combine2018["Bench Press"], c='green', alpha=0.5)
plt.ylim(.5,20)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Bench Press', fontsize=15)
plt.title('Bench Press for 2018 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2008["Position"], combine2008["Max Vertical(in)"], c='red', alpha=0.5)
plt.ylim(25,42.5)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Max Vertical(in)', fontsize=15)
plt.title('Maximum Vertical for 2008 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2008["Position"], combine2008["Lane Agility(sec)"], c='blue', alpha=0.5)
plt.ylim(10,14)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Lane Agility (sec)', fontsize=15)
plt.title('Lane Agility for 2008 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2008["Position"], combine2008["Three Quarter Sprint"], c='green', alpha=0.5)
plt.ylim(3,3.8)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Three Quarter Sprint (sec)', fontsize=15)
plt.title('Three Quarter Sprint (sec) for 2008 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2008["Position"], combine2008["Bench Press"], c='green', alpha=0.5)
plt.ylim(.5,27)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Bench Press', fontsize=15)
plt.title('Bench Press for 2008 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2000["Position"], combine2000["Max Vertical(in)"], c='red', alpha=0.5)
plt.ylim(20,44)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Max Vertical(in)', fontsize=15)
plt.title('Maximum Vertical for 2000 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2000["Position"], combine2000["Lane Agility(sec)"], c='blue', alpha=0.5)
plt.ylim(10,14)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Lane Agility (sec)', fontsize=15)
plt.title('Lane Agility for 2000 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2000["Position"], combine2000["Three Quarter Sprint"], c='green', alpha=0.5)
plt.ylim(2.8,3.8)
plt.xlabel('Positions', fontsize=15)
plt.ylabel('Three Quarter Sprint (sec)', fontsize=15)
plt.title('Three Quarter Sprint (sec) for 2000 Draft Class', fontsize=20)
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.scatter(combine2000["Position"], combine2000["Bench Press"], c='green', alpha=0.5)
plt.ylim(.5,25)
plt.ylabel('Bench Press', fontsize=15)
plt.xlabel("Positions", fontsize=15)
plt.title('Bench Press for 2000 Draft Class', fontsize=20)
plt.grid()
plt.show()
